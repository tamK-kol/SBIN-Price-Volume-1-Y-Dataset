# %%
pip install nselib
# Out:
# ...
#   Obtaining dependency information for nselib from https://files.pythonhosted.org/packages/b4/32/1a47ee0cae35624153d23ce5bd52983c1e6528b1e6e98f64d1fa5699f1b0/nselib-0.7-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nselib
from nselib import capital_market

# %%
capital_market.price_volume_data('SBIN', period = '1Y')
# Out:
#     Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0      NaN     EQ  29-Dec-2022     601.05     600.00     618.00    597.15
# 1      NaN     EQ  30-Dec-2022     611.80     615.25     620.55    611.35
# 2      NaN     EQ  02-Jan-2023     613.70     614.95     619.20    611.20
# 3      NaN     EQ  03-Jan-2023     612.20     614.50     616.60    610.00
# 4      NaN     EQ  04-Jan-2023     612.40     611.85     614.95    604.00
# ..     ...    ...          ...        ...        ...        ...       ...
# 243    NaN     EQ  22-Dec-2023     643.75     644.75     649.40    635.15
# 244    NaN     EQ  26-Dec-2023     636.75     638.85     641.30    635.65
# 245    NaN     EQ  27-Dec-2023     638.05     640.75     649.45    639.00
# 246    NaN     EQ  28-Dec-2023     648.55     650.25     653.30    646.50
# 247    NaN     EQ  29-Dec-2023     651.40     645.50     649.60    639.55
#
#      LastPrice  ClosePrice  AveragePrice TotalTradedQuantity Turnover  \
# ...
